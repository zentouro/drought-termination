# %% [markdown]
# ### CMIP6 Drought Anomaly: Pre & Post processing, model, and timeseries export
#
# The following code:
#  - downloads & saves models from CMIP6 according to specified experiments & variables
#  - selects & saves specified AR6 regions
#  - calculates & saves anomalies across all variables

# %% [markdown]
# ### Required Packages

# %%
# data import
import zarr
import intake
from dask.diagnostics import ProgressBar

import numpy as np
import pandas as pd
import xarray as xr
import dask 
import datetime

xr.set_options(display_style='html')
import cftime
import nc_time_axis

import warnings
warnings.filterwarnings("ignore")

# progress bars for loops
from tqdm.notebook import tqdm  

## plotting
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import regionmask

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 6)

from IPython import display
display.set_matplotlib_formats('retina')

# %% [markdown]
# ### TO DO:
# - turn helper functions into a utility package

# %%
#import sys
#sys.path.append('~/drought-termination/code/CMIP6_utils.py')
#import CMIP6_utils

# %% [markdown]
# ### Helper Functions

# %%
def fix_lon(ds):
    '''
    adjust longitude to be [-180, 180]
    '''
    ds = ds.copy()
    
    ## TO DO FIGURE OUT HOW TO KEEP LONGITUDE ATTRIBUTES 
    if ds.lon.max()>180:
        ds.coords['lon'] = ((ds.coords['lon'] + 180) % 360 - 180) 
        ds = ds.sortby(ds.lon)

    return ds

def fix_time(ds):
    '''
    reformat time data to be a cftime.datetime object with year, month, day=1, calendar='proleptic_gregorian'
    '''
    ds = ds.copy()
    
    # get time tuples, in the form (year, month, ... )
    time_tuples = [t.timetuple() for t in ds.coords['time'].data]
    #ds.coords['time'] = [cftime.datetime(time_tuple[0], time_tuple[1], 1, calendar='proleptic_gregorian')
    #                     for time_tuple in time_tuples]
    
    ds.coords['time'] = [cftime.datetime(time_tuple[0], time_tuple[1], time_tuple[2], calendar='proleptic_gregorian')
                         for time_tuple in time_tuples]
    
    return ds


def wrapper(ds):
    '''
    clean up newly imported data
    '''
    ds = ds.copy()
    
    if ('longitude' in ds.dims) and ('latitude' in ds.dims):
        ds = ds.rename({'longitude':'lon', 'latitude': 'lat'}) # some models labelled dimensions differently...
    if ('bnds' in ds.dims): 
        ds=ds.drop_dims('bnds')
    if ('vertex' in ds.dims): 
        ds=ds.drop_dims('vertex')
    if ('height' in ds.dims): 
        ds=ds.drop_dims('height')
    if ('height' in ds): 
        ds=ds.drop_vars('height') 
    if ('depth' in ds.dims):
        ds=ds.drop_dims('depth')
    if ('depth' in ds): 
        ds=ds.drop_vars('depth') 
    
    
    # clean up the different calendars and get them all using the same cftime (hopefully)
    ds = fix_time(ds)
    # fix longitude values across all the models 
    ds = fix_lon(ds)
    return ds



### GLOBAL MEANS ###
def get_lat_name(ds):
    for lat_name in ['lat', 'latitude']:
        if lat_name in ds.coords:
            return lat_name
    raise RuntimeError("Couldn't find a latitude coordinate")

def global_mean(ds):
    """
    Calculate weighted global mean average
    """
    lat = ds[get_lat_name(ds)]
    weight = np.cos(np.deg2rad(lat))
    weight /= weight.mean()
    other_dims = set(ds.dims) - {'time'} - {'year'} - {'member_id'}
    return (ds * weight).mean(other_dims)

def region_select(ds, region_params):
    """
    subset a dataset by region
    """
    region_ds = ds.sel(lat=slice(*region_params['lat']), lon=slice(*region_params['lon']))
    return region_ds


### ANOMALIES ###

def anomalies(ds, model):
    '''
    Returns timeseries of anomalies (globally averaged) for a given dataset.
    '''
    try:  
        baseline = ds.sel(time = slice('1861', '1880')).groupby('time.month')
        ds_standard = (ds.groupby('time.month') - baseline.mean())/baseline.std()
        ds_anom = global_mean(ds_standard)
        return ds_anom
    except:
        print('***** error calculating ' + str(model) + ' anomalies *****')   

### RESPONSES ###

def responses(ds):
    """
    Calculate difference between early and late period.
    Lazy.
    """

    ds = ds.copy()
    
    early_start = '1861'
    early_end = '1880'
    early = ds.sel(time=slice(early_start, early_end)).mean(dim = 'time')
    
    late_start = '2050'
    late_end = '2100'
    late = ds.sel(time = slice(late_start, late_end)).mean(dim = 'time')
    
    difference = (late - early)/early.std()
    
    return difference

# %% [markdown]
# ## Variable, Model, Experiment, and Region Selection for Querying pangeo CMIP6 datastore
#
# I've loaded data models that include surface soil moisture (`mrsos`), temperature (`tas`), and precipitation (`pr`) at the monthly timescale (`Amon` for atmospheric variables and `Lmon` for land variables) for the historical time period and future scenario, `ssp585`. This can, of course, be adjusted to look for different variables and scenarios.
#
# I've also loaded data for total column moisture (`mrso`) and precipitation (`pr`).
#
# For more information on the available data and naming conventions check out [this google doc](https://docs.google.com/document/d/1h0r8RZr_f3-8egBMMh7aqLwy3snpD6_MrDz1q8n5XUk/edit), the more up-to-date [github](https://github.com/WCRP-CMIP/CMIP6_CVs/ ), or [this excel spreadsheet has all the MIP Variable names](https://cmip6dr.github.io/Data_Request_Home/Documents/MIPVariableNames.xls).

# %%
#variable_id = ['mrsos', 'pr', 'tas']
#variable_id = ['mrso', 'pr']
variable_id = ['mrsos', 'mrso', 'pr', 'tas']

source_id = [
    #'ACCESS-CM2', 'BCC-CSM2-MR', 'CAMS-CSM1-0',	'CNRM-CM6-1', 'CNRM-ESM2-1', 'CanESM5-CanOE', 
    'EC-Earth3-Veg', 'FIO-ESM-2-0', 'GFDL-CM4',
    'IPSL-CM6A-LR', 'MIROC-ES2L',  'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR',
    'MRI-ESM2-0', 'UKESM1-0-LL' , 'MIROC6' #,'CanESM5' 
]

experiment_id = ['historical', 'ssp585']

# %%
col = intake.open_esm_datastore("https://storage.googleapis.com/cmip6/pangeo-cmip6.json")


# form query dictionary
query = dict(experiment_id = experiment_id, 
             variable_id = variable_id, 
             # to use all available models comment out this line and the preceeding comma
             # however, i am unsure if all models will work 
             source_id = source_id
            ) 

# subset catalog and get some metrics grouped by 'source_id' and 'member_id' as I only want
# models that run from the historical into the scenario on the same experimental forcing
col_subset = col.search(require_all_on=['source_id', 'member_id'], **query)

# just grab the monthly atmosphere and land 
cat = col_subset.search(table_id = ['Amon', 'Lmon'])

# %%
cat.df.groupby('source_id')[['experiment_id', 'variable_id', 'member_id']].nunique()
# Out:
#                experiment_id  variable_id  member_id
# source_id
# EC-Earth3-Veg              2            4          2
# GFDL-CM4                   2            4          1
# IPSL-CM6A-LR               2            4          6
# MIROC-ES2L                 2            4          1
# MIROC6                     2            4          3
# MPI-ESM1-2-HR              2            4          2
# MPI-ESM1-2-LR              2            4          3
# MRI-ESM2-0                 2            4          1
# UKESM1-0-LL                2            4          5

# %%
dset_dict = cat.to_dataset_dict(
    zarr_kwargs={"consolidated": True, "decode_times": True, "use_cftime": True}, 
    preprocess = wrapper
)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='38' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [38/38 00:15<00:00]
#     </div>

# %%
modelnames = {}

dset_concat = {}

for model in tqdm(list(cat.df['source_id'].unique())):
    # makes a list of long names
    # sorts alphabetically
    modelnames[model] = sorted(list({k : v for k, v in dset_dict.items() if model in k}.keys()))
    
    # make a dictionary of the concat (to combine full time series) and merged (to combine variables)
    dset_concat[model] = xr.merge([xr.concat([dset_dict[modelnames[model][0]], dset_dict[modelnames[model][2]]], dim = 'time'),
                                   xr.concat([dset_dict[modelnames[model][1]], dset_dict[modelnames[model][3]]], dim = 'time')])
    
models = modelnames.keys()
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %% [markdown]
# ## Load Models

# %%
dset_concat_load = {model : {} for model in models}

for model in tqdm(dset_concat_load.keys()):
    print("starting " + str(model))
    ds = dset_concat[model].load()
    dset_concat_load[model] = ds
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# starting EC-Earth3-Veg
# starting GFDL-CM4
# starting IPSL-CM6A-LR
# starting MIROC-ES2L
# starting MIROC6
# starting MPI-ESM1-2-HR
# starting MPI-ESM1-2-LR
# starting MRI-ESM2-0
# starting UKESM1-0-LL

# %%
# %time dset_concat_load['EC-Earth3-Veg'].mean(dim = 'time').mean(dim = 'member_id').tas.plot()
# Out:
# CPU times: user 1min 19s, sys: 2min 27s, total: 3min 46s
# Wall time: 7min 40s

# %% [markdown]
# ## Save Full Model Data
# Get the path's playing nice (only run this once, otherwise you need to set the path manually). This also assumes your path defaults to the folder in which this notebook exists.

# %%
import os
from pathlib import Path

os.getcwd()
# Out:
# '/Users/miriam/Documents/02_Academia/02_PhD/research/projects/drought-termination'

# %%
# grab the default path
p=Path(os.getcwd())

# move up a directory
os.chdir(p.parent)

# save that location
project_prefix = os.getcwd()

# %%
project_prefix
# Out:
# '/Users/miriam/Documents/02_Academia/02_PhD/research/projects/drought-termination'

# %% [markdown]
# Export drought anomalies for later analysis

# %%
import re
import glob

print_string = "-"

fn_prefix = '/exported_data/' + print_string.join(experiment_id) + '/'

# %%
## THIS FROZE ON EC-Earth3-Veg
## Check that file and then re-do with just the remaining models

# Output them
for model in dset_concat_load:
    print('starting ' + str(model))
    try:
        dset_concat_load[model].to_netcdf(project_prefix + fn_prefix + model + '_' + print_string.join(variable_id))
    except:
        print(str(model) + ' did not save')
# Out:
# starting EC-Earth3-Veg
# starting GFDL-CM4
# starting IPSL-CM6A-LR
# IPSL-CM6A-LR did not save
# starting MIROC-ES2L
# starting MIROC6
# starting MPI-ESM1-2-HR
# starting MPI-ESM1-2-LR
# starting MRI-ESM2-0
# starting UKESM1-0-LL

# %% [markdown]
# IPSL-CM6A-LR had the additional dimension 'axis_nbounds' that seemed to be causing issues with saving. The following code removes that dimesions and then saves. If this functions properly, add this to pre-processing.

# %%
dset_concat['IPSL-CM6A-LR'].drop_dims('axis_nbounds').to_netcdf(project_prefix + fn_prefix + 'IPSL-CM6A-LR' + '_' + print_string.join(variable_id))

# %% [markdown]
# ## Check exports

# %% [markdown]
# To load the data for later use:

# %%
# get filelist
fns = glob.glob(project_prefix + fn_prefix + '*')

# get the 'key' that was used earlier - just using 
# regex to get the string after the last "_" or "/", which 
# is how to get the ks based on what i made the fn_prefix 

# above
#ks = [re.split('\_',fn)[-1] for fn in fns]
ks = [re.split('\/',fn)[-1] for fn in fns]
models = [re.split('_', k)[0] for k in ks]

# Load
dict_of_ds = dict()
for (k, model) in zip(ks, models):
    dict_of_ds[model] = xr.open_dataset(project_prefix + fn_prefix+k)

# %%
# dict_of_ds['IPSL-CM6A-LR_mrsos-mrso-pr-tas']
# something is wrong with the IPSL downloaded data
# removing this model for now

dict_of_ds.pop('IPSL-CM6A-LR')
models.remove('IPSL-CM6A-LR')

# %% [markdown]
# ## Check units
#
# Everyone was supposed to follow the directions, but double check that they are correct

# %%
for model in dict_of_ds.keys():
    try:
        print(model + '\n column moisture units: ' + dict_of_ds[model].mrso.attrs['units'] + 
             ', surface soil units: ' + dict_of_ds[model].mrsos.attrs['units'] + ', precipitation units: ' + 
              dict_of_ds[model].pr.attrs['units'])
    except:
        print('error on ' + model)
# Out:
# CanESM5
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# CAMS-CSM1-0
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# MIROC-ES2L
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# GFDL-CM4
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# ACCESS-CM2
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# UKESM1-0-LL
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# MRI-ESM2-0
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# MPI-ESM1-2-HR
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# CNRM-ESM2-1
#  column moisture units: kg m-2, surface soil units: kg m-2, precipitation units: kg m-2 s-1
# BCC-CSM2-MR
# ...

# %% [markdown]
# ___________________________________
#
# ## Regional Selection
#
# I'm interested in looking at the regions the the AR6 regions in which "there is at least medium confidence in increase in agriculture/ecological drought at the 2°C warming level ("drying regions"), including W. North-America, C. North-America, N. Central-America, S. Central-America, N. South-America, N. E. South-America, South-American-Monsoon, S.W.South- America, S.South-America, West & Central-Europe, Mediterranean, W.Southern-Africa, E.Southern- Africa, Madagascar, E.Australia, S.Australia "
#
# Regions (in 7 grouped subdivisions) ~ up for discussion:
# - Europe: Mediterranean, West & Central-Europe | MED, WCE
# - N. America: W. North-America, C. North-America | WNA, CNA
# - C. America:  N. Central-America, S. Central-America | NCA, SCA
# - Northern S.: America: N. South-America, N. E. South-America, South-American-Monsoon | NSA, NES, SAM
# - Southern S.: America: S.W.South- America, S.South-America | SWS, SSA
# - Africa: W.Southern-Africa, E.Southern-Africa, Madagascar | WSAF, ESAF, MDG
# - Australia: E.Australia, S.Australia | SAU, EAU

# %%
text_kws = dict(color = "#67000d", fontsize = 7, bbox = dict(pad = 0.2, color = "w"))

# for all regions
#regionmask.defined_regions.ar6.all.plot(text_kws = text_kws, add_ocean = True, add_land=True, label='abbrev');

# for drying regions
regionmask.defined_regions.ar6.all[['MED', 'WCE', 'WNA', 'CNA', 
                                    'NCA', 'SCA', 'NSA', 'NES', 
                                    'SAM', 'SWS', 'SSA', 'WSAF', 
                                    'ESAF', 'MDG', 'SAU', 'EAU']].plot(text_kws = text_kws, 
                                                                       add_ocean = True, 
                                                                       add_land = True, 
                                                                       label = 'abbrev');

plt.tight_layout()

# %% [markdown]
# # TO DO
#
# - find anomalies
# - find drought events
#    - rewrite drought detection as not recursion?
# - send drought event csv to Ben
# - figure out superposed epoch analysis

# %%
def region_select(ds, region_codes):
    """ 
    region codes are defined by the regionmask package. more information is available in their documentation:
    https://regionmask.readthedocs.io/en/stable/defined_scientific.html
    
    region_codes: [list, of, region, codes]
    """ 
    ar6_region = regionmask.defined_regions.ar6.all
    mask = regionmask.defined_regions.ar6.all.mask(ds)
    ds_select = ds.where(xr.concat([mask == ar6_region.map_keys(region) for region in region_codes], dim='comp').max('comp'), drop = True)
    
    return ds_select

# %% [markdown]
# ### Check on a single model to make sure everything works (well enough for now)

# %%
ds = dict_of_ds['MIROC6']
regions = ['WCE','MED']

ds_select = region_select(ds, regions)

fig, ax = plt.subplots(subplot_kw = {'projection': ccrs.Robinson()})
ds_select.mrso[0][0].plot(cmap = 'BrBG', ax = ax, transform = ccrs.PlateCarree())
ax.coastlines(zorder = 3)
# Out:
# ['WCE', 'MED']

# %% [markdown]
# ### Grab the regions for each model

# %%
dict_of_EUR = {model : {} for model in models}
dict_of_NA = {model : {} for model in models}

EUR_regions = ['MED', 'WCE']
NA_regions = ['WNA', 'CNA']

for model in tqdm(models):
    print('starting ' + model)
    dict_of_EUR[model] = region_select(dict_of_ds[model], EUR_regions)
    dict_of_NA[model] = region_select(dict_of_ds[model], NA_regions)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# starting CanESM5
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting CAMS-CSM1-0
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting MIROC-ES2L
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting GFDL-CM4
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting ACCESS-CM2
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting UKESM1-0-LL
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting MRI-ESM2-0
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting MPI-ESM1-2-HR
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting CNRM-ESM2-1
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting BCC-CSM2-MR
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting MPI-ESM1-2-LR
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting CanESM5-CanOE
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting MIROC6
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting CNRM-CM6-1
# ['MED', 'WCE']
# ['WNA', 'CNA']
# starting EC-Earth3-Veg
# ['MED', 'WCE']
# ['WNA', 'CNA']

# %% [markdown]
# - not sure why some models have lat/lons without data resulting in the striping below

# %%
nrows = 5
ncols = 3

fig, axarr = plt.subplots(nrows = nrows, ncols = ncols, figsize = [15, 15], subplot_kw={"projection": ccrs.Robinson()})

for ax, model in zip(axarr.flat, dict_of_EUR.keys()):
    dict_of_EUR[model].mrsos[0][0].plot(cmap = 'BrBG', ax = ax, transform = ccrs.PlateCarree())
    ax.coastlines(zorder = 3)
    ax.set_title(model)

# %% [markdown]
# - total column (below) scale varies widely
# - is this because the depth is different across models?

# %%
fig, axarr = plt.subplots(nrows = nrows, ncols = ncols, figsize = [15, 15], subplot_kw={"projection": ccrs.Robinson()})

for ax, model in zip(axarr.flat, dict_of_EUR.keys()):
    dict_of_EUR[model].mrso[0][0].plot(cmap = 'BrBG', ax = ax, transform = ccrs.PlateCarree())
    ax.coastlines(zorder = 3)
    ax.set_title(model)

# %% [markdown]
# ### Save files

# %%
fn_prefix = '/exported_data/regions/' + print_string.join(EUR_regions) + '/'

# %%
for model in tqdm(dict_of_EUR):
    print('starting ' + str(model))
    try:
        dict_of_EUR[model].to_netcdf(project_prefix + fn_prefix + model + '_' + print_string.join(variable_id) + '.nc')
    except:
        print(str(model) + ' did not save')
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# starting CanESM5
# starting CAMS-CSM1-0
# starting MIROC-ES2L
# starting GFDL-CM4
# starting ACCESS-CM2
# starting UKESM1-0-LL
# starting MRI-ESM2-0
# starting MPI-ESM1-2-HR
# starting CNRM-ESM2-1
# starting BCC-CSM2-MR
# starting MPI-ESM1-2-LR
# starting CanESM5-CanOE
# starting MIROC6
# starting CNRM-CM6-1
# starting EC-Earth3-Veg

# %%
fn_prefix = '/exported_data/regions/' + print_string.join(NA_regions) + '/' 

for model in tqdm(dict_of_NA):
    print('starting ' + str(model))
    try:
        dict_of_NA[model].to_netcdf(project_prefix + fn_prefix + model + '_' + print_string.join(variable_id) + '.nc')
    except:
        print(str(model) + ' did not save')
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# starting CanESM5
# starting CAMS-CSM1-0
# starting MIROC-ES2L
# starting GFDL-CM4
# starting ACCESS-CM2
# starting UKESM1-0-LL
# starting MRI-ESM2-0
# starting MPI-ESM1-2-HR
# starting CNRM-ESM2-1
# starting BCC-CSM2-MR
# starting MPI-ESM1-2-LR
# starting CanESM5-CanOE
# starting MIROC6
# starting CNRM-CM6-1
# starting EC-Earth3-Veg

# %% [markdown]
# ## Calculate Model Anomalies

# %%
# IMPORT EUROPEAN REGIONS

fn_prefix = '/exported_data/regions/' + print_string.join(EUR_regions) + '/' 
# get filelist
fns = glob.glob(project_prefix + fn_prefix + '*')

# get the 'key' that was used earlier - just using 
# regex to get the string after the last "_" or "/", which 
# is how to get the ks based on what i made the fn_prefix 

# above
#ks = [re.split('\_',fn)[-1] for fn in fns]
ks = [re.split('\/',fn)[-1] for fn in fns]
models = [re.split('_', k)[0] for k in ks]

# Load
dict_of_EU = dict()
for (k, model) in zip(ks, models):
    dict_of_EU[model] = xr.open_dataset(project_prefix + fn_prefix+k)

# %%
dict_of_EU.keys()
# Out:
# dict_keys(['BCC-CSM2-MR', 'CNRM-ESM2-1', 'UKESM1-0-LL', 'MPI-ESM1-2-LR', 'CNRM-CM6-1', 'MIROC-ES2L', 'MRI-ESM2-0', 'CAMS-CSM1-0', 'CanESM5', 'GFDL-CM4', 'MPI-ESM1-2-HR', 'ACCESS-CM2', 'MIROC6', 'EC-Earth3-Veg', 'CanESM5-CanOE'])

# %%
dict_of_EU['BCC-CSM2-MR'].pr
# Out:
# <xarray.DataArray 'pr' (member_id: 1, time: 3012, lat: 56, lon: 44)>
# [7421568 values with dtype=float32]
# Coordinates:
#   * lat        (lat) float64 30.84 30.84 31.96 31.96 ... 60.0 60.0 61.12 61.12
#   * lon        (lon) float64 -9.0 -7.875 -6.75 -5.625 ... 36.0 37.12 38.25 39.38
#   * time       (time) datetime64[ns] 1850-01-16 1850-02-15 ... 2100-12-16
#   * member_id  (member_id) object 'r1i1p1f1'
# Attributes:
#     cell_measures:  area: areacella
#     cell_methods:   area: time: mean (interval: 5 minutes)
#     comment:        includes both liquid and solid phases
#     long_name:      Precipitation
#     original_name:  PRECT
#     standard_name:  precipitation_flux
#     units:          kg m-2 s-1

# %% [markdown]
# ## Drought Index
#
# Steps:
# 1. Loops through each available model and loads information for the specified region.
# 2. Creates a baseline, grouped by month, for the 1861-1880 time period.
# 3. Standardizes
# 4. Takes a weighted mean to create a timeseries.
#
# The following code block loads the data into memory, this can take a while.

# %%
model_anoms = {model : {} for model in models}

for model in tqdm(model_anoms.keys()):
    print("starting " + str(model))
    ds = region_select(dset_concat[model], region_params).load()
    model_anoms[model] = anomalies(ds, model)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# starting ACCESS-CM2
# starting BCC-CSM2-MR
# starting CAMS-CSM1-0
# starting CNRM-CM6-1
# starting CNRM-ESM2-1
# starting CanESM5
# ***** error calculating CanESM5 anomalies *****
# starting CanESM5-CanOE
# starting EC-Earth3-Veg
# starting GFDL-CM4
# starting IPSL-CM6A-LR
# starting MIROC-ES2L
# starting MIROC6
# starting MPI-ESM1-2-HR
# starting MPI-ESM1-2-LR
# starting MRI-ESM2-0
# starting UKESM1-0-LL
# ***** error calculating UKESM1-0-LL anomalies *****

# %%
dict_of_ds
# Out:
# {'MIROC-ES2L': <xarray.Dataset>
#  Dimensions:    (member_id: 1, time: 3012)
#  Coordinates:
#    * time       (time) datetime64[ns] 1850-01-16 1850-02-15 ... 2100-12-16
#    * member_id  (member_id) object 'r1i1p1f2'
#  Data variables:
#      pr         (member_id, time) float64 ...
#      mrso       (member_id, time) float64 ...,
#  'ACCESS-CM2': <xarray.Dataset>
#  Dimensions:    (member_id: 3, time: 5412)
#  Coordinates:
#    * time       (time) datetime64[ns] 1850-01-16 ... 1716-05-27T00:25:26.29044...
#    * member_id  (member_id) object 'r1i1p1f1' 'r2i1p1f1' 'r3i1p1f1'
#  Data variables:
#      pr         (member_id, time) float64 ...
#      mrso       (member_id, time) float64 ...,
#  'CNRM-ESM2-1': <xarray.Dataset>
#  Dimensions:    (member_id: 5, time: 3012)
#  Coordinates:
#    * time       (time) datetime64[ns] 1850-01-16 1850-02-15 ... 2100-12-16
#    * member_id  (member_id) object 'r1i1p1f2' 'r2i1p1f2' ... 'r5i1p1f2'
#  Data variables:
# ...
